# %%
import math
import numpy
import matplotlib
import matplotlib.pyplot as plt

difference = []

def iteration(f, a, b, EPS):
    if abs(b - a) >= EPS:
        a1 = a + abs(a - b) / 1.62
        b1 = b - abs(a1 - b) / 1.62
        difference.append(abs(a - b))
        if f(a1) > f(b1):
            return iteration(f, a1, b, EPS)
        else:
            return iteration(f, a, b1, EPS)
    else:
        return a, b
        
def f(x):
    return (-1) * math.cos(x)

def minimum(f, a, b, EPS):
    result = iteration(f, a, b, EPS)
    return (result[1] + result[0]) / 2



a = 4.5
b = 6.5
print(iteration(f, a, b, 10 ** (-8)))
# Out:
# (6.283185290369879, 6.283185298335629)

# %%
x = numpy.arange(a - 0.5, b + 0.5, 0.002)
minimum_1 = minimum(f, a, b, 10 ** (-8))
plt.plot(x, [f(el) for el in x], ',')
plt.plot(x, [f(minimum_1) for el in x], ',')
plt.grid(True)
plt.show()

# %%
plt.semilogy(range(len(difference)),  difference)
plt.grid(True)
plt.show()
